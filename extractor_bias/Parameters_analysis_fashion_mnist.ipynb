# %%
import torch
from pprint import pprint
import matplotlib.pyplot as plt

# %% [markdown]
# ### Fashion Mnist f1

# %%
model = torch.load("Fase_1_fashion_mnist.pth")
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(1.1173, device='cuda:0')),
#  (1, tensor(1.1761, device='cuda:0')),
#  (2, tensor(0.9395, device='cuda:0')),
#  (3, tensor(1.0210, device='cuda:0')),
#  (4, tensor(0.9797, device='cuda:0')),
#  (5, tensor(1.0964, device='cuda:0')),
#  (6, tensor(1.1480, device='cuda:0')),
#  (7, tensor(1.1745, device='cuda:0')),
#  (8, tensor(1.0812, device='cuda:0')),
#  (9, tensor(1.1608, device='cuda:0'))]
# Bias:
# [(0, tensor(0.0672, device='cuda:0')),
#  (1, tensor(0.0397, device='cuda:0')),
#  (2, tensor(-0.0077, device='cuda:0')),
#  (3, tensor(0.0239, device='cuda:0')),
#  (4, tensor(-0.1433, device='cuda:0')),
#  (5, tensor(0.4709, device='cuda:0')),
#  (6, tensor(-0.0521, device='cuda:0')),
#  (7, tensor(0.0403, device='cuda:0')),
#  (8, tensor(-0.2079, device='cuda:0')),
#  (9, tensor(-0.2249, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()

# %% [markdown]
# ### Fashion mnist f0

# %%
model = torch.load("Fase_0_fashion_mnist.pth")
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(1.1468, device='cuda:0')),
#  (1, tensor(1.1634, device='cuda:0')),
#  (2, tensor(0.9770, device='cuda:0')),
#  (3, tensor(1.0278, device='cuda:0')),
#  (4, tensor(1.0447, device='cuda:0')),
#  (5, tensor(0.6434, device='cuda:0')),
#  (6, tensor(0.6459, device='cuda:0')),
#  (7, tensor(0.6459, device='cuda:0')),
#  (8, tensor(0.6364, device='cuda:0')),
#  (9, tensor(0.6301, device='cuda:0'))]
# Bias:
# [(0, tensor(0.1295, device='cuda:0')),
#  (1, tensor(0.1075, device='cuda:0')),
#  (2, tensor(0.0790, device='cuda:0')),
#  (3, tensor(0.0990, device='cuda:0')),
#  (4, tensor(-0.0536, device='cuda:0')),
#  (5, tensor(-0.0491, device='cuda:0')),
#  (6, tensor(-0.0558, device='cuda:0')),
#  (7, tensor(-0.0544, device='cuda:0')),
#  (8, tensor(-0.0940, device='cuda:0')),
#  (9, tensor(-0.1022, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos ')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()
