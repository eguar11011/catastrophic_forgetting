# %%
import torch
from pprint import pprint
import matplotlib.pyplot as plt

# %% [markdown]
# ### Fashion Mnist f1

# %%
model = torch.load("Fase_1_K_mnist.pth")
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(1.1454, device='cuda:0')),
#  (1, tensor(1.2011, device='cuda:0')),
#  (2, tensor(1.1623, device='cuda:0')),
#  (3, tensor(1.1398, device='cuda:0')),
#  (4, tensor(1.1058, device='cuda:0')),
#  (5, tensor(1.3225, device='cuda:0')),
#  (6, tensor(1.1660, device='cuda:0')),
#  (7, tensor(1.2610, device='cuda:0')),
#  (8, tensor(1.3301, device='cuda:0')),
#  (9, tensor(1.2617, device='cuda:0'))]
# Bias:
# [(0, tensor(-0.0302, device='cuda:0')),
#  (1, tensor(0.1261, device='cuda:0')),
#  (2, tensor(0.1129, device='cuda:0')),
#  (3, tensor(0.1251, device='cuda:0')),
#  (4, tensor(-0.1550, device='cuda:0')),
#  (5, tensor(0.0587, device='cuda:0')),
#  (6, tensor(-0.0835, device='cuda:0')),
#  (7, tensor(-0.1828, device='cuda:0')),
#  (8, tensor(0.0273, device='cuda:0')),
#  (9, tensor(-0.0179, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()

# %% [markdown]
# ### Fashion mnist f0

# %%
model = torch.load("Fase_0_K_mnist.pth")
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(1.2556, device='cuda:0')),
#  (1, tensor(1.2929, device='cuda:0')),
#  (2, tensor(1.2667, device='cuda:0')),
#  (3, tensor(1.2567, device='cuda:0')),
#  (4, tensor(1.1808, device='cuda:0')),
#  (5, tensor(0.6634, device='cuda:0')),
#  (6, tensor(0.6445, device='cuda:0')),
#  (7, tensor(0.6516, device='cuda:0')),
#  (8, tensor(0.6617, device='cuda:0')),
#  (9, tensor(0.6692, device='cuda:0'))]
# Bias:
# [(0, tensor(0.0422, device='cuda:0')),
#  (1, tensor(0.2005, device='cuda:0')),
#  (2, tensor(0.1977, device='cuda:0')),
#  (3, tensor(0.2140, device='cuda:0')),
#  (4, tensor(-0.0937, device='cuda:0')),
#  (5, tensor(-0.1105, device='cuda:0')),
#  (6, tensor(-0.0890, device='cuda:0')),
#  (7, tensor(-0.1145, device='cuda:0')),
#  (8, tensor(-0.1353, device='cuda:0')),
#  (9, tensor(-0.1307, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos ')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()
