# %%
import torch
from pprint import pprint
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cifar10

# %%
model = torch.load("Fase_1_cifar10.pth")
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(0.8684, device='cuda:0')),
#  (1, tensor(0.8579, device='cuda:0')),
#  (2, tensor(0.8909, device='cuda:0')),
#  (3, tensor(0.8986, device='cuda:0')),
#  (4, tensor(0.8839, device='cuda:0')),
#  (5, tensor(0.9027, device='cuda:0')),
#  (6, tensor(0.9259, device='cuda:0')),
#  (7, tensor(0.8989, device='cuda:0')),
#  (8, tensor(0.9190, device='cuda:0')),
#  (9, tensor(0.9275, device='cuda:0'))]
# Bias:
# [(0, tensor(0.0156, device='cuda:0')),
#  (1, tensor(-0.0335, device='cuda:0')),
#  (2, tensor(0.0298, device='cuda:0')),
#  (3, tensor(0.0358, device='cuda:0')),
#  (4, tensor(0.0333, device='cuda:0')),
#  (5, tensor(0.0089, device='cuda:0')),
#  (6, tensor(0.0039, device='cuda:0')),
#  (7, tensor(0.0290, device='cuda:0')),
#  (8, tensor(0.0007, device='cuda:0')),
#  (9, tensor(-0.0013, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()

# %% [markdown]
# ### Cifar10 f0

# %%
model = torch.load("Fase_0_cifar10.pth")
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(0.9332, device='cuda:0')),
#  (1, tensor(0.9197, device='cuda:0')),
#  (2, tensor(0.9490, device='cuda:0')),
#  (3, tensor(0.9597, device='cuda:0')),
#  (4, tensor(0.9391, device='cuda:0')),
#  (5, tensor(0.6156, device='cuda:0')),
#  (6, tensor(0.6221, device='cuda:0')),
#  (7, tensor(0.6189, device='cuda:0')),
#  (8, tensor(0.6191, device='cuda:0')),
#  (9, tensor(0.6139, device='cuda:0'))]
# Bias:
# [(0, tensor(0.0366, device='cuda:0')),
#  (1, tensor(-0.0114, device='cuda:0')),
#  (2, tensor(0.0495, device='cuda:0')),
#  (3, tensor(0.0553, device='cuda:0')),
#  (4, tensor(0.0528, device='cuda:0')),
#  (5, tensor(-0.0110, device='cuda:0')),
#  (6, tensor(-0.0169, device='cuda:0')),
#  (7, tensor(0.0112, device='cuda:0')),
#  (8, tensor(-0.0179, device='cuda:0')),
#  (9, tensor(-0.0263, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos ')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()
