# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import ast
import os

# %% [markdown]
# ### Fase 0

# %%
# Configurar la cuadrícula de subgráficos
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 10))

# Iterar sobre los archivos y las ubicaciones de subgráficos
for i, ax in enumerate(axes.flatten()):
    # Crear el nombre del archivo
    file_name = f'logs/epoch_{i}_CC_0.txt'
    
    # Verificar si el archivo existe
    if os.path.exists(file_name):
        # Abre el archivo en modo de lectura ('r')
        with open(file_name, 'r') as archivo:
            # Lee el contenido del archivo
            contenido = archivo.read()
            
            # Convierte la expresión literal de Python en la estructura de datos original
            data = ast.literal_eval(contenido)

        # Extraer etiquetas reales y predicciones
        real_labels, predicted_labels = zip(*data)

        # Crear una matriz de confusión
        conf_matrix = confusion_matrix(real_labels, predicted_labels)

        # Crear un mapa de calor en el subgráfico actual
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis',
                    xticklabels=set(real_labels), yticklabels=set(real_labels), ax=ax)

        # Añadir etiquetas a los ejes
        ax.set_xlabel('Predicted Label')
        ax.set_ylabel('True Label')
        ax.set_title(f'Epoch {i}')

# Ajustar diseño y mostrar el mosaico de mapas de calor
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Fase 1

# %%
# Configurar la cuadrícula de subgráficos
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 10))

# Iterar sobre los archivos y las ubicaciones de subgráficos
for i, ax in enumerate(axes.flatten()):
    # Crear el nombre del archivo
    file_name = f'logs/epoch_{i}_CC_1.txt'
    
    # Verificar si el archivo existe
    if os.path.exists(file_name):
        # Abre el archivo en modo de lectura ('r')
        with open(file_name, 'r') as archivo:
            # Lee el contenido del archivo
            contenido = archivo.read()
            
            # Convierte la expresión literal de Python en la estructura de datos original
            data = ast.literal_eval(contenido)

        # Extraer etiquetas reales y predicciones
        real_labels, predicted_labels = zip(*data)

        # Crear una matriz de confusión
        conf_matrix = confusion_matrix(real_labels, predicted_labels)

        # Crear un mapa de calor en el subgráfico actual
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis',
                    xticklabels=set(real_labels), yticklabels=set(real_labels), ax=ax)

        # Añadir etiquetas a los ejes
        ax.set_xlabel('Predicted Label')
        ax.set_ylabel('True Label')
        ax.set_title(f'Epoch {i}')

# Ajustar diseño y mostrar el mosaico de mapas de calor
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Modelo 1 con Clasificador f0(0-4) y f1(5-9)

# %%
# Configurar la cuadrícula de subgráficos
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Iterar sobre los archivos y las ubicaciones de subgráficos
for i, ax in enumerate(axes.flatten()):
    # Crear el nombre del archivo
    file_name = f'logs/preditions_combination_classifier_f0_0_4_f1_5_9_F1.txt'
    
    # Verificar si el archivo existe
    if os.path.exists(file_name):
        # Abre el archivo en modo de lectura ('r')
        with open(file_name, 'r') as archivo:
            # Lee el contenido del archivo
            contenido = archivo.read()
            
            # Convierte la expresión literal de Python en la estructura de datos original
            data = ast.literal_eval(contenido)

        # Extraer etiquetas reales y predicciones
        real_labels, predicted_labels = zip(*data)

        # Crear una matriz de confusión
        conf_matrix = confusion_matrix(real_labels, predicted_labels)

        # Crear un mapa de calor en el subgráfico actual
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis',
                    xticklabels=set(real_labels), yticklabels=set(real_labels), ax=ax)

        # Añadir etiquetas a los ejes
        ax.set_xlabel('Predicted Label')
        ax.set_ylabel('True Label')
        ax.set_title(f'Epoch {i}')

# Ajustar diseño y mostrar el mosaico de mapas de calor
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Modelo 1 con clasificador f1(0-4) y f0(5-9)

# %%
# Configurar la cuadrícula de subgráficos
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Iterar sobre los archivos y las ubicaciones de subgráficos
for i, ax in enumerate(axes.flatten()):
    # Crear el nombre del archivo
    file_name = f'logs/preditions_combination_classifier_f1_0_4_f0_5_9_F1.txt'
    
    # Verificar si el archivo existe
    if os.path.exists(file_name):
        # Abre el archivo en modo de lectura ('r')
        with open(file_name, 'r') as archivo:
            # Lee el contenido del archivo
            contenido = archivo.read()
            
            # Convierte la expresión literal de Python en la estructura de datos original
            data = ast.literal_eval(contenido)

        # Extraer etiquetas reales y predicciones
        real_labels, predicted_labels = zip(*data)

        # Crear una matriz de confusión
        conf_matrix = confusion_matrix(real_labels, predicted_labels)

        # Crear un mapa de calor en el subgráfico actual
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis',
                    xticklabels=set(real_labels), yticklabels=set(real_labels), ax=ax)

        # Añadir etiquetas a los ejes
        ax.set_xlabel('Predicted Label')
        ax.set_ylabel('True Label')
        ax.set_title(f'Epoch {i}')

# Ajustar diseño y mostrar el mosaico de mapas de calor
plt.tight_layout()
plt.show()

# %% [markdown]
# - ¿Por que este clasificador es bueno?

# %% [markdown]
# ### Modelo 0 con Clasificador f0(0-4) y f1(5-9)

# %%
# Configurar la cuadrícula de subgráficos
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Iterar sobre los archivos y las ubicaciones de subgráficos
for i, ax in enumerate(axes.flatten()):
    # Crear el nombre del archivo
    file_name = f'logs/preditions_combination_classifier_f1_0_4_f0_5_9_F0.txt'
    
    # Verificar si el archivo existe
    if os.path.exists(file_name):
        # Abre el archivo en modo de lectura ('r')
        with open(file_name, 'r') as archivo:
            # Lee el contenido del archivo
            contenido = archivo.read()
            
            # Convierte la expresión literal de Python en la estructura de datos original
            data = ast.literal_eval(contenido)

        # Extraer etiquetas reales y predicciones
        real_labels, predicted_labels = zip(*data)

        # Crear una matriz de confusión
        conf_matrix = confusion_matrix(real_labels, predicted_labels)

        # Crear un mapa de calor en el subgráfico actual
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis',
                    xticklabels=set(real_labels), yticklabels=set(real_labels), ax=ax)

        # Añadir etiquetas a los ejes
        ax.set_xlabel('Predicted Label')
        ax.set_ylabel('True Label')
        ax.set_title(f'Epoch {i}')

# Ajustar diseño y mostrar el mosaico de mapas de calor
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Modelo 0 con Clasificador f1(0-4) y f0(5-9)

# %%
# Configurar la cuadrícula de subgráficos
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Iterar sobre los archivos y las ubicaciones de subgráficos
for i, ax in enumerate(axes.flatten()):
    # Crear el nombre del archivo
    file_name = f'logs/preditions_combination_classifier_f0_0_4_f1_5_9_F0.txt'
    
    # Verificar si el archivo existe
    if os.path.exists(file_name):
        # Abre el archivo en modo de lectura ('r')
        with open(file_name, 'r') as archivo:
            # Lee el contenido del archivo
            contenido = archivo.read()
            
            # Convierte la expresión literal de Python en la estructura de datos original
            data = ast.literal_eval(contenido)

        # Extraer etiquetas reales y predicciones
        real_labels, predicted_labels = zip(*data)

        # Crear una matriz de confusión
        conf_matrix = confusion_matrix(real_labels, predicted_labels)

        # Crear un mapa de calor en el subgráfico actual
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis',
                    xticklabels=set(real_labels), yticklabels=set(real_labels), ax=ax)

        # Añadir etiquetas a los ejes
        ax.set_xlabel('Predicted Label')
        ax.set_ylabel('True Label')
        ax.set_title(f'Epoch {i}')

# Ajustar diseño y mostrar el mosaico de mapas de calor
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# - Parece que las capas anteriores al clasificador influyen bastante para que la ultima capa pueda clasificar correctamente.
# - En estos experimentos. Los clasificadores no pueden discriminar cosas que nunca han visto.

# %% [markdown]
# ## Extrator F1 con clasificador F0

# %%
# Configurar la cuadrícula de subgráficos
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

# Iterar sobre los archivos y las ubicaciones de subgráficos
for i, ax in enumerate(axes.flatten()):
    # Crear el nombre del archivo
    file_name = f'logs/preditions_combination_classifier_f0_0_4_f0_5_9_F1.txt'
    
    # Verificar si el archivo existe
    if os.path.exists(file_name):
        # Abre el archivo en modo de lectura ('r')
        with open(file_name, 'r') as archivo:
            # Lee el contenido del archivo
            contenido = archivo.read()
            
            # Convierte la expresión literal de Python en la estructura de datos original
            data = ast.literal_eval(contenido)

        # Extraer etiquetas reales y predicciones
        real_labels, predicted_labels = zip(*data)

        # Crear una matriz de confusión
        conf_matrix = confusion_matrix(real_labels, predicted_labels)

        # Crear un mapa de calor en el subgráfico actual
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis',
                    xticklabels=set(real_labels), yticklabels=set(real_labels), ax=ax)

        # Añadir etiquetas a los ejes
        ax.set_xlabel('Predicted Label')
        ax.set_ylabel('True Label')
        ax.set_title(f'Epoch {i}')

# Ajustar diseño y mostrar el mosaico de mapas de calor
plt.tight_layout()
plt.show()
