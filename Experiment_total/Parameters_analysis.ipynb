# %%
import torch
from pprint import pprint
import matplotlib.pyplot as plt

# %%
model = torch.load("Total.pth")

# %%
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(1.0102, device='cuda:0')),
#  (1, tensor(1.0155, device='cuda:0')),
#  (2, tensor(1.0322, device='cuda:0')),
#  (3, tensor(1.0142, device='cuda:0')),
#  (4, tensor(1.0244, device='cuda:0')),
#  (5, tensor(1.0312, device='cuda:0')),
#  (6, tensor(1.0539, device='cuda:0')),
#  (7, tensor(1.0531, device='cuda:0')),
#  (8, tensor(0.9685, device='cuda:0')),
#  (9, tensor(1.0117, device='cuda:0'))]
# Bias:
# [(0, tensor(-0.0180, device='cuda:0')),
#  (1, tensor(0.0037, device='cuda:0')),
#  (2, tensor(0.0205, device='cuda:0')),
#  (3, tensor(0.0213, device='cuda:0')),
#  (4, tensor(0.0391, device='cuda:0')),
#  (5, tensor(0.0308, device='cuda:0')),
#  (6, tensor(0.0019, device='cuda:0')),
#  (7, tensor(0.0448, device='cuda:0')),
#  (8, tensor(-0.0380, device='cuda:0')),
#  (9, tensor(-0.0177, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos F1')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias F1')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()
