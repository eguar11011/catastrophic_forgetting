# %%
import torch
from pprint import pprint
import matplotlib.pyplot as plt

# %% [markdown]
# ### Fase 8

# %%
model = torch.load("Fase_8.pth")

# %%
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(0.7358, device='cuda:0')),
#  (1, tensor(0.7328, device='cuda:0')),
#  (2, tensor(0.6369, device='cuda:0')),
#  (3, tensor(0.6497, device='cuda:0')),
#  (4, tensor(0.6315, device='cuda:0')),
#  (5, tensor(0.6463, device='cuda:0')),
#  (6, tensor(0.6727, device='cuda:0')),
#  (7, tensor(0.6390, device='cuda:0')),
#  (8, tensor(1.0444, device='cuda:0')),
#  (9, tensor(0.6456, device='cuda:0'))]
# Bias:
# [(0, tensor(-0.0385, device='cuda:0')),
#  (1, tensor(0.1295, device='cuda:0')),
#  (2, tensor(-0.0431, device='cuda:0')),
#  (3, tensor(-0.0485, device='cuda:0')),
#  (4, tensor(0.0250, device='cuda:0')),
#  (5, tensor(-0.0517, device='cuda:0')),
#  (6, tensor(-0.0621, device='cuda:0')),
#  (7, tensor(0.0453, device='cuda:0')),
#  (8, tensor(0.0915, device='cuda:0')),
#  (9, tensor(-0.0577, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()

# %% [markdown]
# ### Fase 1

# %%
model = torch.load("Fase_1.pth")
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(0.7815, device='cuda:0')),
#  (1, tensor(1.1554, device='cuda:0')),
#  (2, tensor(0.6104, device='cuda:0')),
#  (3, tensor(0.5922, device='cuda:0')),
#  (4, tensor(0.5968, device='cuda:0')),
#  (5, tensor(0.6147, device='cuda:0')),
#  (6, tensor(0.6037, device='cuda:0')),
#  (7, tensor(0.5889, device='cuda:0')),
#  (8, tensor(0.6219, device='cuda:0')),
#  (9, tensor(0.5916, device='cuda:0'))]
# Bias:
# [(0, tensor(0.0630, device='cuda:0')),
#  (1, tensor(0.3211, device='cuda:0')),
#  (2, tensor(-0.0384, device='cuda:0')),
#  (3, tensor(-0.0413, device='cuda:0')),
#  (4, tensor(-0.0250, device='cuda:0')),
#  (5, tensor(-0.0706, device='cuda:0')),
#  (6, tensor(-0.0910, device='cuda:0')),
#  (7, tensor(-0.0588, device='cuda:0')),
#  (8, tensor(-0.0478, device='cuda:0')),
#  (9, tensor(-0.0214, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()

# %% [markdown]
# ### Tuneando la fase 1

# %%
model = torch.load("Tuning_Fase_1.pth")
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(2.4506, device='cuda:0')),
#  (1, tensor(2.6987, device='cuda:0')),
#  (2, tensor(1.4599, device='cuda:0')),
#  (3, tensor(1.4783, device='cuda:0')),
#  (4, tensor(1.4441, device='cuda:0')),
#  (5, tensor(1.2086, device='cuda:0')),
#  (6, tensor(1.6918, device='cuda:0')),
#  (7, tensor(1.6071, device='cuda:0')),
#  (8, tensor(1.2822, device='cuda:0')),
#  (9, tensor(1.2694, device='cuda:0'))]
# Bias:
# [(0, tensor(-0.3797, device='cuda:0')),
#  (1, tensor(0.4907, device='cuda:0')),
#  (2, tensor(-0.2718, device='cuda:0')),
#  (3, tensor(-0.2611, device='cuda:0')),
#  (4, tensor(0.4543, device='cuda:0')),
#  (5, tensor(-0.0025, device='cuda:0')),
#  (6, tensor(-0.0870, device='cuda:0')),
#  (7, tensor(0.4085, device='cuda:0')),
#  (8, tensor(-0.5665, device='cuda:0')),
#  (9, tensor(0.2048, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos ')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()

# %% [markdown]
# ### Tuneando la fase 8

# %%
model = torch.load("Tuning_Fase_8.pth")
print("Weights Norm:")
wn = [(indice ,torch.norm(row) ) for indice ,row in enumerate(model["linear_relu_stack.4.weight"])]
pprint(wn)
print("Bias:")
bias = [(indice ,row ) for indice ,row in enumerate(model["linear_relu_stack.4.bias"])]
pprint(bias)
# Out:
# Weights Norm:
# [(0, tensor(2.5836, device='cuda:0')),
#  (1, tensor(2.7475, device='cuda:0')),
#  (2, tensor(1.7190, device='cuda:0')),
#  (3, tensor(2.0177, device='cuda:0')),
#  (4, tensor(1.9795, device='cuda:0')),
#  (5, tensor(1.4532, device='cuda:0')),
#  (6, tensor(2.2926, device='cuda:0')),
#  (7, tensor(2.3179, device='cuda:0')),
#  (8, tensor(1.4219, device='cuda:0')),
#  (9, tensor(1.6158, device='cuda:0'))]
# Bias:
# [(0, tensor(-0.2410, device='cuda:0')),
#  (1, tensor(0.6335, device='cuda:0')),
#  (2, tensor(-0.2088, device='cuda:0')),
#  (3, tensor(-0.1591, device='cuda:0')),
#  (4, tensor(0.1851, device='cuda:0')),
#  (5, tensor(0.0864, device='cuda:0')),
#  (6, tensor(-0.0760, device='cuda:0')),
#  (7, tensor(0.2492, device='cuda:0')),
#  (8, tensor(-0.4652, device='cuda:0')),
#  (9, tensor(-0.0144, device='cuda:0'))]

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in wn]
y = [item[1].item() for item in wn]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Norma de los pesos ')
plt.grid(True)
plt.axvline(5, color = "r")
plt.show()

# %%
# Convertir los datos en listas separadas para x e y
x = [item[0] for item in bias]
y = [item[1].item() for item in bias]  # Convertir los tensores a valores numéricos

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Clases')
plt.ylabel('Valor')
plt.title('Valos Bias')
plt.grid(True)

plt.axvline(5, color = "r")
plt.show()
